# %% [markdown]
# <h3>Pokemons</h3>
# <hr/>
# <div style='width:40%'>
#
# ![image-2.png](attachment:image-2.png)
#
# </div>

# %%
# Task : Load the Dataset

# %%
# Loaded!!

# %%
d={'Grass': 70, 'Fire': 52, 'Water': 112, 'Bug': 69, 'Normal': 98, 'Poison': 28, 'Electric': 44, 'Ground': 32, 'Fairy': 17, 'Fighting': 27, 'Psychic': 57, 'Rock': 44, 'Ghost': 32, 'Ice': 24, 'Dragon': 32, 'Dark': 31, 'Steel': 27, 'Flying': 4}

# %%
d
# Out:
# {'Grass': 70,
#  'Fire': 52,
#  'Water': 112,
#  'Bug': 69,
#  'Normal': 98,
#  'Poison': 28,
#  'Electric': 44,
#  'Ground': 32,
#  'Fairy': 17,
#  'Fighting': 27,
#  'Psychic': 57,
#  'Rock': 44,
#  'Ghost': 32,
#  'Ice': 24,
#  'Dragon': 32,
#  'Dark': 31,
#  'Steel': 27,
#  'Flying': 4}

# %%
sorted(d.items(),key=lambda x : x[1], reverse=True)
# Out:
# [('Water', 112),
#  ('Normal', 98),
#  ('Grass', 70),
#  ('Bug', 69),
#  ('Psychic', 57),
#  ('Fire', 52),
#  ('Electric', 44),
#  ('Rock', 44),
#  ('Ground', 32),
#  ('Ghost', 32),
#  ('Dragon', 32),
#  ('Dark', 31),
#  ('Poison', 28),
#  ('Fighting', 27),
#  ('Steel', 27),
#  ('Ice', 24),
#  ('Fairy', 17),
#  ('Flying', 4)]

# %%
typ1 compat typ2

# %%
# %time 
sum([1,2,3])
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs
# 6

# %%
µs- microsecond 1 million part of a second
ns- nano second 1 thousand-millionth part of second

# %%
import pandas as pd

# %%
df= pd.read_csv('/Users/rajan/Downloads/access_log')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-21-548b0c5f5d8b> in <module>
# ----> 1 df= pd.read_csv('/Users/rajan/Downloads/access_log')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
# ...
